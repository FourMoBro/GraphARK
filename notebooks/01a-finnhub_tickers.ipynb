# %%
import os
import finnhub
from dotenv import load_dotenv, find_dotenv
import psycopg2
import psycopg2.extras

# %%
load_dotenv(find_dotenv())
# Out:
# True

# %%
api_key2 = os.environ.get("FINNHUB_API_KEY")
host2 = os.environ.get("DB_HOST")
database2 = os.environ.get("DB_NAME")
user2 = os.environ.get("DB_USER")
password2 = os.environ.get("DB_PASSWORD")

# %%
finnhub_client = finnhub.Client(api_key=api_key2)

# %%
stock_list = finnhub_client.stock_symbols('US')
len(stock_list)
# Out:
# 27729

# %%
stock_list

# %%
connection = psycopg2.connect(host=host2, database=database2, user=user2, password=password2)

# %%
cursor = connection.cursor(cursor_factory=psycopg2.extras.DictCursor)

# %%
for stock in stock_list:
    
    print(f"Inserting stock {stock.get('description')} {stock.get('symbol')}")
    cursor.execute("""
        INSERT INTO tickers (description, symbol, figi, type) 
        VALUES (%s, %s, %s, %s)
    """, (stock.get('description'), stock.get('symbol'), stock.get('figi'), stock.get('type')))

connection.commit()
# Out:
# Inserting stock GRAYSCALE BITCOIN CASH TRUST BCHG
# Inserting stock VICTREX PLC-UNSP ADR VTXPY
# Inserting stock AMICUS THERAPEUTICS INC FOLD
# Inserting stock  ATEST
# Inserting stock HAVERTY FURNITURE HVT
# Inserting stock LANTERN PHARMA INC LTRN
# Inserting stock BANK CENTRAL ASIA TBK PT PBCRF
# Inserting stock APTUS COLLARED INC OPP ETF ACIO
# Inserting stock IREN SPA IRDEF
# Inserting stock CHANJET INFORMATION TECH-H CJETF
# Inserting stock NRC GROUP ASA NNRRF
# Inserting stock ESPORTS TECHNOLOGIES INC EBET
# Inserting stock PAX CLEAN ENERGY INC PXCE
# Inserting stock GEOPETRO RESOURCES CO GEOR
# Inserting stock HK EBUS CORP HKEB
# Inserting stock AXM PHARMA INC AXMP
# Inserting stock ADC THERAPEUTICS SA ADCT
# Inserting stock STAKEHOLDER GOLD CORP SKHRF
# Inserting stock EAST WEST PETROLEUM CORP EWPMF
# Inserting stock FLOW CAPITAL CORP AHFCF
# Inserting stock OVERLAY SHARES SHRT TERM BON OVT
# Inserting stock EMAMBA INTERNATIONAL CORP EMBA
# Inserting stock FAVO CAPITAL INC FAVO
# Inserting stock DYNAGAS LNG PARTNERS LP DLNG.PRB
# Inserting stock PLAINS GP HOLDINGS LP-CL A PAGP
# Inserting stock SPERO THERAPEUTICS INC SPRO
# Inserting stock DEVMAR EQUITIES INC DEVM
# Inserting stock AGROFRESH SOLUTIONS INC AGFS
# Inserting stock GRUPO LALA SAB DE CV GRPBF
# Inserting stock MAPLETREE INDUSTRIAL TRUST MAPIF
# Inserting stock ALGONQUIN PWR & UTILITY AQNA
# Inserting stock CRESCO LTD CEJOF
# Inserting stock FIRST INTL BANK ISRAEL FBKIF
# Inserting stock VORTEX BRANDS CO VTXB
# Inserting stock GREEN ENERGY GROUP INC GRYG
# Inserting stock BANK OF AYUDHYA PCL-UNS ADR BKAYY
# Inserting stock RENEWABLE CORP/THE RNWB
# Inserting stock EUROPEAN CLEANTECH SE-CW15 ETNPF
# Inserting stock CONSOLIDATED COMMUNICATIONS CNSL
# Inserting stock SEERTECH CORP STCRQ
# Inserting stock TATA CONSUMER PROD-SPONS GDR TTAEY
# Inserting stock AGORA INC-ADR API
# Inserting stock HKBN LTD - UNSPON ADR HKBNY
# Inserting stock NEW ENGLAND REALTY ASSOC-LP NEN
# Inserting stock BULL HORN HOLDINGS CORP BHSE
# Inserting stock NORTHSHORE GLOBAL URANIUM MI URNM
# Inserting stock MEGAFON-REG S GDR MFOYY
# Inserting stock KEURIG DR PEPPER INC KDP
# Inserting stock AGBA ACQUISITION LTD AGBAU
# Inserting stock ODAKYU ELECTRIC RAILWAY CO ODERF
# Inserting stock COLOPLAST-B CLPBF
# Inserting stock CBRE ACQ HOLDINGS A -CW27 CBAH.WS
# Inserting stock IPATH BLOOMBERG NATURAL GAS GAZZF
# Inserting stock RECON TECHNOLOGY LTD-CLASS A RCON
# Inserting stock IPATH BLOOMBERG ALUMINUM SUB JJUFF
# Inserting stock NITCHES INC NICH
# Inserting stock DUCK CREEK TECHNOLOGIES INC DCT
# Inserting stock ERIN VENTURES INC ERVFF
# Inserting stock GRAN COLOMBIA GOLD CORP-CW24 TPRXF
# Inserting stock WISDOMTREE INTERNATIONAL MUL DWMF
# Inserting stock IVANHOE MINES LTD-CL A IVPAF
# Inserting stock SOLAR ENERTECH CORP SOEN
# Inserting stock CALVIN B. TAYLOR BANKSHARES TYCB
# Inserting stock WEST JAPAN RAILWAY CO WJRYF
# Inserting stock ASTRONOVA INC ALOT
# Inserting stock CAPITAL GROUP HOLDINGS INC CGHC
# Inserting stock ORANGE FNCTF
# Inserting stock SANMINA CORP SANM
# Inserting stock AMERICAN CENTURY DIVERSIFIED KORP
# Inserting stock ISHARES ESG MSCI USA LEADERS SUSL
# Inserting stock ACRES COMMERCIAL REALTY CORP ACR
# Inserting stock KALNORTH GOLD MINES LTD CKGDF
# Inserting stock UNITED ENERGY CORP/NEVADA UNRG
# Inserting stock KUNLUN ENERGY CO LTD KUNUF
# Inserting stock CYXTERA TECHNOLOGIES INC CYXT
# Inserting stock ALTAIR INTERNATIONAL CORP ATAO
# Inserting stock HUDSON EXECUTIVE INV A -CW28 HIIIW
# Inserting stock FRASER AND NEAVE LTD-UNS ADR FNEVY
# Inserting stock MING FAI INTL HLDGS LTD MFAIF
# Inserting stock UNICAJA BANCO SA UNJCF
# Inserting stock TOOTSIE ROLL INDUSTRIES-CL B TROLB
# Inserting stock ELEMENTAL ROYALTIES CORP ELEMF
# Inserting stock C3 METALS CORP CARCF
# Inserting stock EQUITABLE HOLDINGS INC EQH.PRC
# Inserting stock FIRST SOLAR INC FSLR
# Inserting stock QUANTUM CAPITAL INC QTCI
# Inserting stock GIVEMEPOWER CORP GMPW
# Inserting stock FIDELITY CORPORATE BOND ETF FCOR
# Inserting stock NOKIA OYJ NOKBF
# Inserting stock VANECK CAMC CHINA BOND CBON
# Inserting stock ROUCHON INDUSTRIES INC RCHN
# Inserting stock TIGER BRANDS LTD TBLMF
# Inserting stock HANESBRANDS INC HBI
# Inserting stock PENTAMASTER INTERNATIONAL LT PNMRF
# Inserting stock AEGON NV AEGOF
# Inserting stock SENTRY SEL PRIMARY METALS-A SPMLF
# Inserting stock SONIC AUTOMOTIVE INC-CLASS A SAH
# Inserting stock COLUMBIA SPORTSWEAR CO COLM
# Inserting stock QUARTERHILL INC QTRHF
# Inserting stock NASDAQ 7 HANDL INDEX ETF HNDL
# Inserting stock SINTX TECHNOLOGIES INC-CW23 AMDDW
# Inserting stock CENTRAL JAPAN RAI-UNSPON ADR CJPRY
# Inserting stock KEIYO BANK LTD/THE KEIBF
# Inserting stock BADGER STATE ETHANOL - CAP U BADG
# Inserting stock DAI-ICHI LIFE HOLD INC UNSP DLICY
# Inserting stock YOOX NET-A-PORTER GROUP YXOXF
# Inserting stock GENERAL EUROPEAN STRATEGIC I GESI
# Inserting stock SIREN LARGE CAP BLEND INDEX SPQQ
# Inserting stock UP FINTECH HOLDING LTD - ADR TIGR
# Inserting stock KEPPEL INFRASTRUCTURE TRUST KPLIF
# Inserting stock SQUARE ENIX HOLDINGS CO LTD SQNXF
# Inserting stock CHINA RESOURCES LAND-UNS ADR CRBJY
# Inserting stock CYBIN INC CLXPF
# Inserting stock VANECK VECTORS SOC SENT ETF BUZZ
# Inserting stock PACER SWAN SOS FUND OF FUNDS PSFF
# Inserting stock SINOPEC ENGINRING GRP-H ADR SNPRY
# Inserting stock DKSH HOLDING AG DKSHF
# Inserting stock BEL SA FGRBF
# Inserting stock KINKI SHARYO CO LTD KSCLF
# Inserting stock DIXIE LEE INTERNATIONAL INDU DLII
# Inserting stock CRESTWOOD EQUITY PARTNERS LP CEQP
# Inserting stock POWER SOLUTIONS INTERNATIONA PSIX
# Inserting stock NATIONWIDE RISK-BASED INTL E RBIN
# Inserting stock GLOBAL PAYMENTS INC GPN
# Inserting stock NICHOLAS FINANCIAL INC NICK
# Inserting stock U S LIQUIDS INC USLQ
# Inserting stock VIB VERMOEGEN AG-UNSP ADR VIBVY
# Inserting stock DMY TECHNOLOGY GR III-CL A DMYI
# Inserting stock SIGNIFY HEALTH INC -CLASS A SGFY
# Inserting stock PHI GROUP INC-CW44 PHIGW
# Inserting stock FREEDOM DAY DIVIDEND ETF MBOX
# Inserting stock AMERICA MOVIL SAB DE C-SER L AMXVF
# Inserting stock CHINA XD PLASTICS CO LTD CXDC
# Inserting stock ACM RESEARCH INC-CLASS A ACMR
# Inserting stock INCEPTION MINING INC IMII
# Inserting stock K & S CORP LTD KSCNF
# Inserting stock GEOVENCAP INC GVCPF
# Inserting stock SUMMIT HOTEL PROPERTIES INN.PRD
# Inserting stock THRYV HOLDINGS INC-CW23 THRYW
# Inserting stock LAI FUNG HOLDINGS LTD LFHLF
# Inserting stock ANHUI CONCH CEMENT CO LTD-H AHCHF
# Inserting stock STADA ARZNEIMITTEL AG STDAF
# Inserting stock TLG ACQUISITION ONE CORP TLGA.U
# Inserting stock SANRIO CO LTD SNROF
# Inserting stock JAMES RIVER HOLDINGS CORP JRIV
# Inserting stock TELESITES SAB DE CV TSSLF
# Inserting stock APRIA INC APR
# Inserting stock SPDR S&P US HEALTH SELECT SSEHF
# Inserting stock THANACHART CAPITAL-FOREIGN THNVF
# Inserting stock DIASORIN SPA DSRLF
# Inserting stock ACADEMY SPORTS & OUTDOORS IN ASO
# Inserting stock VIPER ENERGY PARTNERS LP VNOM
# Inserting stock AEGLEA BIOTHERAPEUTICS INC AGLE
# Inserting stock QUANTUM FINTECH ACQUISITION QFTA.U
# Inserting stock CLOOPEN GROUP HOLDING LTD RAAS
# Inserting stock SAFARI CORP SFRI
# Inserting stock GLOBAL NET LEASE INC GNL.PRA
# Inserting stock OLEMA PHARMACEUTICALS INC OLMA
# Inserting stock GREENWAY TECHNOLOGY GWYT
# Inserting stock NOVUS ROBOTICS INC NRBT
# Inserting stock SANDFIRE RESOURCES LTD SFRRF
# Inserting stock HORIZON GLOBAL CORP HZN
# Inserting stock CRINETICS PHARMACEUTICALS IN CRNX
# Inserting stock INFINITY PHARMACEUTICALS INC INFI
# Inserting stock DIGITAL MEDIA SOL - CW23 DMS.WS
# Inserting stock RLX TECHNOLOGY INC-ADR RLX
# Inserting stock SPDR PORT INT TREASURY TERM SPTI
# Inserting stock MANZO PHARMACEUTICALS INC MNZO
# Inserting stock INVESTINDUSTRIAL ACQ-CLASS A IIAC
# Inserting stock ISHARES CORE DIVIDEND GROWTH DGRO
# Inserting stock TEXAS MINERAL RESOURCES CORP TMRC
# Inserting stock LIFETIME BRANDS INC LCUT
# Inserting stock ISHARES INTL DIV GROWTH ETF IGRO
# Inserting stock BRIGHT MOUNTAIN MEDIA INC BMTM
# Inserting stock KUSHCO HOLDINGS INC KSHB
# Inserting stock WESTECH CAPITAL CORP WTECQ
# Inserting stock HARVEST HEALTH & RECREATION HRVSF
# Inserting stock GORES METROPOULOS II INC GMIIU
# Inserting stock ETRACS ALERIAN MDSTR ENER TR AMTR
# Inserting stock STI GROUP INC STUO
# Inserting stock URANIUM ENERGY CORP UEC
# Inserting stock COLICITY INC-A -CW27 COLIW
# Inserting stock UNITED TENNESSEE BANKSHARES UNTN
# Inserting stock KINTOR PHARMACEUTICAL LTD KNTPF
# Inserting stock CHARLESTOWNE PREMIUM BEVERAG FPWM
# Inserting stock THIMBLE POINT ACQ A -CW26 THMAW
# Inserting stock GREEN STAR PRODUCTS INC GSPI
# Inserting stock US SILICA HOLDINGS INC SLCA
# Inserting stock ZEALAND PHARMA A/S-ADR ZEAL
# Inserting stock LONGVIEW ACQUISITION CORP II LGV.U
# Inserting stock PROGRESS SOFTWARE CORP PRGS
# Inserting stock SOBR SAFE INC SOBR
# Inserting stock NIPPON CARBON CO LTD NCRBF
# Inserting stock ANTEOTECH LTD ADONF
# Inserting stock RIVERNORTH OPPORTUNITIES FND RIV
# Inserting stock DEERE & CO DE
# Inserting stock ARCA BIOPHARMA INC ABIO
# Inserting stock ETFMG SIT ULTRA SHORT ETF VALT
# Inserting stock D8 HOLDINGS CORP DEH.U
# Inserting stock ALLIED MOTION TECHNOLOGIES AMOT
# Inserting stock RAMBLER METALS AND MINING PL RBMTF
# Inserting stock WALMART DE MEXICO-SPON ADR V WMMVY
# Inserting stock SUPPORT.COM INC SPRT
# Inserting stock GLANBIA PLC GLAPF
# Inserting stock DELTEX MEDICAL GROUP PLC DTXMF
# Inserting stock DELIVEROO PLC DROOF
# Inserting stock PROTEIN REACTOR COMBINED FUE PRCF
# Inserting stock GOFF CORP GOFF
# Inserting stock BOA ACQUISITION CORP-A BOAS
# Inserting stock MUSK METALS CORP EMSKF
# Inserting stock VIA VAREJO SA -SP ADR GBXPY
# Inserting stock CLUBHOUSE MEDIA GROUP INC CMGR
# Inserting stock IMI PLC IMIAF
# Inserting stock BIDVEST GROUP LTD BDVSF
# Inserting stock GRUPO BIMBO SAB A - SPON ADR BMBOY
# Inserting stock COSTAIN GROUP PLC-UNSP ADR CTNGY
# Inserting stock SEALED AIR CORP SEE
# Inserting stock PROSHARES ULTRA NASDAQ CYBR UCYB
# Inserting stock GLORIUS SUN ENTERPRISES GLSEF
# Inserting stock CLARENT CORP CLRN
# Inserting stock ASTREA ACQUISITION CORP ASAXU
# Inserting stock RETO ECO-SOLUTIONS INC RETO
# Inserting stock RIVERNORTH FLEX MUNI II RFMZ
# Inserting stock NEW CAROLIN GOLD CORP LADFF
# Inserting stock OPTIMUS HEALTHCARE SERVICES OHCS
# Inserting stock ACE HARDWARE INDONE-UNSP ADR PHDWY
# Inserting stock BLACKHAWK BANCORP INC BHWB
# Inserting stock G2 GOLDFIELDS INC GUYGF
# Inserting stock SCHWAB FUNDAMENTAL INTL S/C FNDC
# Inserting stock FEARLESS FILMS INC FERL
# Inserting stock SILEX SYSTEMS LTD SILXF
# Inserting stock ADVANCED EMISSIONS SOLUTIONS ADES
# Inserting stock WHEELER REIT INC WHLRP
# Inserting stock FIRST TRUST GLOBAL ENGINEERI FLM
# Inserting stock NORTHEAST INDIANA BANCORP NIDB
# Inserting stock FLYWIRE CORP-VOTING FLYW
# Inserting stock NEUBERGER BERMAN MUNICIPAL NBH
# Inserting stock NUANCE COMMUNICATIONS INC NUAN
# Inserting stock SYNAIRGEN PLC SYGGF
# Inserting stock CONVATEC GROUP PLC-UNSP ADR CNVVY
# Inserting stock SYNAPTOGENIX INC SNPX
# Inserting stock CYDUCT DIAGNOSTICS INC CYDX
# Inserting stock INSTALLUX SA INSXF
# Inserting stock RESAAS SERVICES INC RSASF
# Inserting stock EQUIFAX INC EFX
# Inserting stock GENESIS HEALTHCARE INC GENN
# Inserting stock 180 LIFE SCIENCES CORP ATNF
# Inserting stock HUDBAY MINERALS INC HBM
# Inserting stock ISHARES S&P 500 GROWTH ETF IVW
# Inserting stock FAMILY ROOM ENTERTAINMENT FMYR
# Inserting stock LYNAS RARE EARTHS LTD-SP ADR LYSDY
# Inserting stock INVENTRUST PROPERTIES CORP IARE
# Inserting stock COMPREHENSIVE CARE CORP CHCR
# Inserting stock FIRST COMMUNITY FINL CORP FMFP
# Inserting stock PGS SOFTWARE SA PGSWF
# Inserting stock UDG HEALTHCARE PL-UNSPON ADR UDRGY
# Inserting stock BLACK MOUNTAIN GOLD USA CORP BMGCF
# Inserting stock SANKYU INC SNKUF
# Inserting stock GRUPO SUPERVIELLE SA-SP ADR SUPV
# Inserting stock AVANTIS INTERNATIONAL EQUITY AVDE
# Inserting stock ISHARES S&P CONSUMER DSCRTN ISRNF
# Inserting stock TELEPHONE & DATA SYSTEM TDA
# Inserting stock ISHARES MSCI JAPAN VALUE ETF EWJV
# Inserting stock BOON INDUSTRIES INC BNOW
# Inserting stock KAL ENERGY INC KALG
# Inserting stock STABILUS SA-UNSP ADR SBLUY
# Inserting stock RED ELECTRICA CORPORACION SA RDEIF
# Inserting stock ARCHER ARHVF
# Inserting stock CITY CHIC COLLECTIVE LTD CCCHF
# Inserting stock ALLIANCE RECOVERY CORP ARVY
# Inserting stock ARIA WIRELESS SYSTEMS INC AWSI
# Inserting stock LIFELINE BIOTECHNOLOGIES INC LLBO
# Inserting stock AURYN MINING CORP AUMC
# Inserting stock ADAMAS PHARMACEUTICALS INC ADMS
# Inserting stock BETAPRO GOLD BULLION 2X DAIL HBCGF
# Inserting stock WETHERSPOON (J.D.) PLC JDWPF
# Inserting stock MEREO BIOPHARMA GROUP PL-ADR MREO
# Inserting stock FIDELITY MAGELLAN ETF FMAG
# Inserting stock CHINA EAST EDUCATION HOLDING CAETF
# Inserting stock MOSAIC CO/THE MOS
# Inserting stock ITALIAN-THAI DEVELOP-FOREIGN ITHDF
# Inserting stock ETRACS 150% CL END FUND ETN CEFD
# Inserting stock TE CONNECTIVITY LTD TEL
# Inserting stock BLUE HORIZON BNE ETF BNE
# Inserting stock BAMBUSER AB BSKZF
# Inserting stock CORE ONE LABS INC CLABD
# Inserting stock WHEREVERTV BROADCASTING CORP TVTV
# Inserting stock TRADESTAR RESOURCES CORP TSRR
# Inserting stock RIVERNORTH SPECIALTY FIN RMPL.PR
# Inserting stock SMART CARD MARKETING SYSTEMS SMKG
# Inserting stock AEMETIS INC AMTX
# Inserting stock SIRIOS RESOURCES INC SIREF
# Inserting stock HERITAGE CANNABIS HOLDINGS C HERTF
# Inserting stock TONIX PHARMACEUTICALS HOLDIN TNXP
# Inserting stock FIRST TRUST MUNICIPAL HIGH I FMHI
# Inserting stock EDGETECH INTERNATIONAL INC EGIL
# Inserting stock SYNTHESIS ENERGY SYSTEMS INC SYNE
# Inserting stock GENERAL DYNAMICS CORP GD
# Inserting stock ASSOC BANC-CORP ASB.PRF
# Inserting stock PLANTATION CORP PTNL
# Inserting stock POP CULTURE GROUP CO LTD-A CPOP
# Inserting stock AMERICAN SECURITY RESOURCES ARSC
# Inserting stock CYBEROPTICS CORP CYBE
# Inserting stock ISHARES MSCI CHINA SMALL-CAP ECNS
# Inserting stock MARATHON OIL CORP MRO
# Inserting stock HORIZONTE MINERALS PLC HZMMF
# Inserting stock ARROW RESERVE CAP MANAG ETF ARCM
# Inserting stock ALTUS STRATEGIES PLC ALTUF
# Inserting stock PROQR THERAPEUTICS NV PRQR
# Inserting stock ISHARES MSCI USA MIN VOL FAC USMV
# Inserting stock IMAGE PROTECT INC IMTL
# Inserting stock PEARSON PLC-SPONSORED ADR PSO
# Inserting stock ALPHA COGNITION INC ACOGF
# Inserting stock Fleury SA UNSP - ADR FLRYY
# Inserting stock SILVERGATE CAPITAL CORP-CL A SI
# Inserting stock MINERVA NEUROSCIENCES INC NERV
# Inserting stock XIANA MINING INC DRIFF
# Inserting stock WISDOM EDUCATION INTERNATION WDMSF
# Inserting stock S/V CLOUD & CYBERSECURITY DI VCLO
# Inserting stock SEAESCAPE ENTERTAINMENT INC SEPI
# Inserting stock LLOYDS BANKING GROUP PLC-ADR LYG
# Inserting stock RED TIGER MINING INC RDTMF
# Inserting stock WATTS WATER TECHNOLOGIES-A WTS
# Inserting stock LEGENDS BUSINESS GROUP INC LGBS
# Inserting stock ISHARES GLOBAL FINANCIALS ET IXG
# Inserting stock TTEC HOLDINGS INC TTEC
# Inserting stock HERITAGE NOLA BANCSHARES INC HRGG
# Inserting stock INFRASTRUCTURE MATERIALS COR IFAM
# Inserting stock GUOCO GROUP LTD GULRF
# Inserting stock HAWAIIAN ELECTRIC INDS HE
# Inserting stock MANDALAY RESOURCES CORP MNDJF
# Inserting stock GS YUASA CORP GYUAF
# Inserting stock ICBS LTD ICBT
# Inserting stock BRIGHTSPHERE INVESTMENT BSA
# Inserting stock UBI BLOCKCHAIN INTERNET LTD UBIA
# Inserting stock TEFRON LTD TFRFF
# Inserting stock Comcast Holdings Corporation CCZ
# Inserting stock VANGUARD HEALTH CARE ETF VHT
# Inserting stock ADVANCED DRAINAGE SYSTEMS IN WMS
# Inserting stock DAY HAGAN/NED DAVIS RESEARCH SSUS
# Inserting stock BAYCOM CORP BCML
# Inserting stock ASPERMONT LTD APMOF
# Inserting stock COUNTRYSIDE PROP PLC-UNS ADR CUSPY
# Inserting stock BLACKPOLL FLEET INTERNATIONA BPOL
# Inserting stock CRUCIBLE ACQUISITION CORP CRU.U
# Inserting stock HMS INCOME FUND INC HMSI
# Inserting stock PANAMERICAN BANCORP PABN
# Inserting stock LOTTE CORP-PREF LTTZF
# Inserting stock JBG SMITH PROPERTIES JBGS
# Inserting stock DOMINO'S PIZZA ENTERPRISES L DPZUF
# Inserting stock PLATINUM STUDIOS INC PDOS
# Inserting stock FIELDS CORP-UNSP ADR FLDYY
# Inserting stock WORLDVEST EQUITY INC WVVEF
# Inserting stock ACRES COMMERCIAL REALTY ACR.PRD
# Inserting stock FLAME ACQUISITION CORP FLME.U
# Inserting stock INSTADOSE PHARMA CORP INSD
# Inserting stock HST GLOBAL INC HSTC
# Inserting stock GROUPON INC GRPN
# Inserting stock ELLINGTON FINANCIAL INC EFC
# Inserting stock HQDA ELDERLY LIFE NETWORK CO HQDA
# Inserting stock GOLDMAN SACHS GROUP INC GS.PRD
# Inserting stock ACADEMY METALS INC URGYF
# Inserting stock AAM S&P EM HIGH DIV VAL ETF EEMD
# Inserting stock MYSALE GROUP PLC MYRPF
# Inserting stock GLOBAL X ROBOTICS & ARTIFICI BOTZ
# Inserting stock SACHEM CAPITAL C SACH.PRA
# Inserting stock ETFMG PRIME CYBER SECURITY E HACK
# Inserting stock MUSTI GROUP OY MTGOF
# Inserting stock CHANGMING INDUSTRIAL MANAGEM CMIM
# Inserting stock ABERDEEN JAPAN EQUITY FUND I JEQ
# Inserting stock TC BANCSHARES INC TCBC
# Inserting stock PROSHARES SHORT OIL & GAS DDG
# Inserting stock POINT BRIDGE GOP STOCK T ETF MAGA
# Inserting stock AMERICAN ACQ -CL A -CW26 AMAOW
# Inserting stock LIGHTSPEED DISCOVERIES INC MURCF
# Inserting stock ADVISORSHARES SAGE CORE RESE HOLD
# Inserting stock BRITANNIA BULK HOLDINGS INC BBLKF
# Inserting stock V.I.P. COMLINK VIPK
# Inserting stock BIOTECH ACQUISITION CO-CL A BIOT
# Inserting stock NATIONAL INSTRUMENTS CORP NATI
# Inserting stock HUMANKIND US STOCK ETF HKND
# Inserting stock DURO FELGUERA SA DUROF
# Inserting stock GREGGS PLC-UNSPONSORED ADR GGGSY
# Inserting stock ISHR MSCI FRONT & SEL EM ETF FM
# Inserting stock HEMISPHERE MEDIA GROUP INC HMTV
# Inserting stock OVID THERAPEUTICS INC OVID
# Inserting stock ABS-CBN HOLDINGS CORP-PDR ABSOF
# Inserting stock INVESCO S&P SMALLCAP 600 QVM QVMS
# Inserting stock INNOLOG HOLDINGS CORP INHC
# Inserting stock AUXICO RESOURCES CANADA INC AUXIF
# Inserting stock KIDVILLE INC KVIL
# Inserting stock RICHLAND RESOURCES INTERNATI RIGG
# Inserting stock VALMET OYJ-UNSP  ADR VLMTY
# Inserting stock FOREST ROAD ACQUISITION CORP FRXB.U
# Inserting stock INVESCO MSCI GLOBAL TIMBER E CUT
# Inserting stock LIGATT SECURITY INTERNATIONA LGTT
# Inserting stock ARTELO BIOSCIENCES INC-CW24 ARTLW
# Inserting stock PAN PACIFIC INTERN-UNSP ADR DQJCY
# Inserting stock CYTOSORBENTS CORP CTSO
# Inserting stock ARNO THERAPEUTICS INC ARNI
# Inserting stock GLOBAL MEDICAL REIT INC GMRE.PRA
# Inserting stock TRADEWEB MARKETS INC-CLASS A TW
# Inserting stock CAPSOURCE FINANCIAL INC CPSO
# Inserting stock READY CAPITAL CORP RC.PRC
# Inserting stock LG HOUSEHOLD & HEALTH CARE LGHHF
# Inserting stock OJSYS INC OJSY
# Inserting stock SANSEI TECHNOLOGIES INC SKUYF
# Inserting stock BURGERFI INTERNATIONAL-CW23 BFIIW
# Inserting stock KAHALA CORP KAHL
# Inserting stock CITADEL EFT INC CDFT
# Inserting stock HOKU CORP HOKUQ
# Inserting stock NUTRA PHARMA CORP NPHC
# Inserting stock ISHARES CORE INTL STOCK ETF IXUS
# Inserting stock ALMONTY INDUSTRIES INC ALMTF
# Inserting stock DAC TECH GROUP INTL INC DAAT
# Inserting stock SPAREBANK 1 HELGELAND HGDPF
# Inserting stock MALLARD ACQUISITION CORP MACUU
# Inserting stock VIRTUS ALLIANZGI CVTF II NCZ.PRA
# Inserting stock SUPERNOVA PARTNERS ACQUISITI SPNV.U
# Inserting stock Test ZXIET
# Inserting stock PHARMING GROUP NV PHGUF
# Inserting stock BODYSCAN CORP BDYS
# Inserting stock IPTV CORPORATION IPTV
# Inserting stock CALUMET SPECIALTY PRODUCTS CLMT
# Inserting stock FIRST TRUST BICK INDEX FUND BICK
# Inserting stock INTERNATIONAL ZEOLITE CORP IZCFF
# Inserting stock NEXI SPA NEXPF
# Inserting stock BEASLEY BROADCAST GRP INC -A BBGI
# Inserting stock MARIFIL MINES LTD MFMLF
# Inserting stock MAYS (J.W.) INC MAYS
# Inserting stock TETRA TECH INC TTEK
# Inserting stock AUDINATE GROUP LTD AUDGF
# Inserting stock SOLARIA ENERGIA Y MEDIO AMBI SEYMF
# Inserting stock ELOS MEDTECH AB ELSBF
# Inserting stock NEXT FUNDS TOPIX BANKS EXCHA TXBUF
# Inserting stock FUEGO ENTERPRISES INC FUGI
# Inserting stock GOLIATH RESOURCES LTD GOTRF
# Inserting stock OPERA LTD-ADR OPRA
# Inserting stock SINGAPORE EXCHANGE-UNSP ADR SPXCY
# Inserting stock PLURISTEM THERAPEUTICS INC PSTI
# Inserting stock AMERICAS GOLD AND SILVER COR USAS
# Inserting stock GTY TECHNOLOGY HOLDINGS INC GTYH
# Inserting stock EVOLUTION AB EVGGF
# Inserting stock ROYAL STANDARD MINERALS INC RYSMF
# Inserting stock LAZURITON NANO BIOTECHNOLOGY LZNN
# Inserting stock COMSTOCK MINING INC LODE
# Inserting stock ALABAMA AIRCRAFT INDUSTRIES AAIIQ
# Inserting stock PATRIOT ENERGY CORP PGYC
# Inserting stock NOVELSTEM INTERNATIONAL CORP NSTM
# Inserting stock XEROS TECHNOLOGY GROUP PLC XRTEF
# Inserting stock PERPETUAL ENERGY INC PMGYF
# Inserting stock BARINGS GL SH DUR HI YLD BGH
# Inserting stock IOWA ETHANOL LLC-CLASS A IWETU
# Inserting stock INVESCO S&P 500 EX-RATE SENS XRLV
# Inserting stock KANDI TECHNOLOGIES GROUP INC KNDI
# Inserting stock INNOVATOR S&P ULTRA BUFF-NOV UNOV
# Inserting stock CENTRICA PLC CPYYF
# Inserting stock FT CBOE VST US EQY DP BUF-MR DMAR
# Inserting stock AMERICAN AIRES INC AAIRF
# Inserting stock NOK AIRLINES CO LTD-NVDR NOKFF
# Inserting stock 3D OIL LTD TOILF
# Inserting stock GUARANTY FEDERAL BNCSHS INC GFED
# Inserting stock INVESCO GOLDEN DRAGON CHINA PGJ
# Inserting stock INVESCO GROWTH MULTI-ASSET A PSMG
# Inserting stock IBRANDS CORP IBRC
# Inserting stock XTRS HI BETA HI YIELD ETF HYUP
# Inserting stock DEOLEO SA SOSCF
# Inserting stock RENASANT CORP RNST
# Inserting stock DB BASE METALS DOUBLE SHORT BOMMF
# Inserting stock M.C.S. STEEL PCL-NVDR MSTUF
# Inserting stock EAGLE MATERIALS INC EXP
# Inserting stock CMS ENERGY CORP CMSD
# Inserting stock ZYNGA INC - CL A ZNGA
# Inserting stock PARADISE ENTERTAINMENT LTD PDSSF
# Inserting stock COLUMBUS MCKINNON CORP/NY CMCO
# Inserting stock CERTIVE SOLUTIONS INC CTVEF
# Inserting stock WESTHAVEN GOLD CORP WTHVF
# Inserting stock LASALLE EXPLORATION CORP LSXEF
# Inserting stock TOKYU CONSTRUCTION CO LTD TYCLF
# Inserting stock FIRST MID BANCSHARES INC FMBH
# Inserting stock ANGEL TELECOM CORP AGLT
# Inserting stock ASFG INC ASFJ
# Inserting stock BLUE THUNDER MINING INC BLTMF
# Inserting stock WESTERN COPPER AND GOLD CORP WRN
# Inserting stock INPOST SA  - UNSP ADR INPOY
# Inserting stock KISMET ACQUISITION ONE-WT KSMTW
# Inserting stock FINEMARK HOLDINGS INC FNBT
# Inserting stock US BANCORP USB.PRR
# Inserting stock ISHARES MSCI CANADA ACC IHCNF
# Inserting stock MOUNT BURGESS MINING NL MTBMF
# Inserting stock SENDAS DISTRIBUIDORA SA ASAI
# Inserting stock CLIMATE REAL IMPACT SOLUTI-A CLIM
# Inserting stock YIK WO INTERNATIONAL HOLDING YIKWF
# Inserting stock PIMCO GLOBAL STOCKSPLUS & IN PGP
# Inserting stock ECOLAB INC ECL
# Inserting stock BIOFRONTERA AG BFFTF
# Inserting stock MUTUAL MERCHANT SERVICES INC MUTM
# Inserting stock B RILEY FINANCIAL INC RILYI
# Inserting stock EXOR NV EXXRF
# Inserting stock BANK PEKAO SA BKPKF
# Inserting stock LAKE VICTORIA MINING CO INC LVCA
# Inserting stock SHIMAO GROUP HOLDINGS LTD SIOPF
# Inserting stock MOVIE STUDIO INC/THE MVES
# Inserting stock PROSHARES ULTRASHORT QQQ QID
# Inserting stock EYEGATE PHARMACEUTICALS EYEG
# Inserting stock LINE Corporation LN
# Inserting stock SEMEN INDONESIA PERSERO TBK PSGTF
# Inserting stock VANG GLBAGG ETF USD H ACC VGRSF
# Inserting stock HACKETT GROUP INC/THE HCKT
# Inserting stock TURMERIC ACQUISITION CORP-A TMPM
# Inserting stock ISHARES MSCI EM ASIA ACC CETFF
# Inserting stock JPM ACTBUILD US LRG CAP EQ JUSA
# Inserting stock CITRON INC CTNI
# Inserting stock IBW FINANCIAL CORPORATION IBWC
# Inserting stock TEMPLE BAR INVESTMENT TRUST TEPBF
# Inserting stock SOCIAL CAPITAL HEDOSOPH VI-A IPOF
# Inserting stock METALORE RESOURCES LTD MTLRF
# Inserting stock PRECIOUS METALS & MINING TRU PMMTF
# Inserting stock BUTTERFLY NETWORK INC BFLY
# Inserting stock DIC CORP DICCF
# Inserting stock DATA KNIGHTS ACQUISITION C-A DKDCA
# Inserting stock JOHN HANCOCK MULT FACT MATER JHMA
# Inserting stock FT CBOE V INTERN EQ BUFF DEC YDEC
# Inserting stock ISHARES CANADIAN HYBRID CORP ICDZF
# Inserting stock FIDELITY INV GRADE BOND ETF FIGB
# Inserting stock INFINITY BANK INFT
# Inserting stock AVATAR VENTURES INC ATAR
# Inserting stock SEKISUI HOUSE LTD SKHSF
# Inserting stock WEST VAULT MINING INC WVMDF
# Inserting stock TINTIC STANDARD GOLD MINES I TNTC
# Inserting stock BANK OF AMERICA CORP BAC.PRP
# Inserting stock CHURCHILL CAPITAL CORP V-A CCV
# Inserting stock IMUGENE LTD IUGNF
# Inserting stock CX NETWORK GROUP INC CXKJ
# Inserting stock CRYPTOSTAR CORP CSTXF
# Inserting stock SIENTRA INC SIEN
# Inserting stock TIANJIN CAPITAL ENVIRON-H TNJIF
# Inserting stock 420 PROPERTY MANAGEMENT INC FTPM
# Inserting stock TEMPUS HOLDINGS LTD TMPHF
# Inserting stock AFFINION GROUP HOLDINGS-CW24 AFFWW
# Inserting stock BIOSIGN TECHNOLOGIES INC BITKF
# Inserting stock GETBUSY PLC GETBF
# Inserting stock FIRST TRUST INDIA NIFTY 50 E NFTY
# Inserting stock AMERICAN WOODMARK CORP AMWD
# Inserting stock MINEWORX TECHNOLOGIES LTD MWXRF
# Inserting stock BLUE SKY URANIUM CORP BKUCF
# Inserting stock FUKUOKA FINANCIAL GROUP-ADR FKKFY
# Inserting stock FIRST TRUST VALUE LINE DVD FUCIF
# Inserting stock INTESA SANPAOLO IITSF
# Inserting stock ARETI WEB INNOVATIONS INC AWEB
# Inserting stock GLOBANT SA GLOB
# Inserting stock POU SHENG INTL HOL-UNSP ADR PSHGY
# Inserting stock GLADSTONE LAND CORP LAND
# Inserting stock PROSHARES ULTRASHORT S&P500 SDS
# Inserting stock GLOBAL CONNECTIONS PCL-NVDR GCRPF
# Inserting stock SUMITOMO METAL MININ-UNS ADR SMMYY
# Inserting stock MIZUHO FINANCIAL GROUP-ADR MFG
# Inserting stock DAIWA HOUSE INDUS-UNSP ADR DWAHY
# Inserting stock KYUSHU RAILWAY CO-UNSPON ADR KYHHY
# Inserting stock WINGSTOP INC WING
# Inserting stock DEEP BLUE MARINE INC DPBE
# Inserting stock INNOVATOR S&P 500 POWER OCT POCT
# Inserting stock WILDSKY RESOURCES INC HWTHF
# Inserting stock INVESCO HI INC 2023 TRGT TRM IHIT
# Inserting stock MIDWEST HOLDING INC MDWT
# Inserting stock ORIENT OVERSEAS-UNSPON ADR OROVY
# Inserting stock GLOBAL X FOUNDER-RUN COMPANI BOSS
# Inserting stock BLUESTEM GROUP INC BGRP
# Inserting stock LEONARDO SPA FINMF
# Inserting stock INVESCO BULLETSHARES 2027 HI BSJR
# Inserting stock AEW UK REIT PLC AEWRF
# Inserting stock SOUTHCREST FINANCIAL GROUP I SCSG
# Inserting stock FIRSTMARK HORIZON ACQUISITIO FMAC.U
# Inserting stock EBANG INTERNATIONAL HLDGS-A EBON
# Inserting stock INNOVATOR US EQY ACCEL 9 BUF XBAP
# Inserting stock US-CHINA BIOMEDICAL TECHNOLO UCBB
# Inserting stock BEACON REDEVELOPMENT INDUSTR BCND
# Inserting stock BIG CYPRESS ACQUISITION CO-W BCYPW
# Inserting stock VENTOUX CCM ACQ -CW25 VTAQW
# Inserting stock BLGI INC BLGI
# Inserting stock SKYLINE INVESTMENTS INC SKLNF
# Inserting stock CHAODA MODERN AGRICULTURE CMGHF
# Inserting stock DAVI LUXURY BRAND GROUP INC MDAV
# Inserting stock ADVISORSHARES GERBER KAWASAK GK
# Inserting stock NALA DIGITAL COMMERCE LTD SHYMF
# Inserting stock CNFINANCE HOLDINGS LTD CNF
# Inserting stock ALABAMA POWER CO ALP.PRQ
# Inserting stock WINTRUST FINANCIAL CORP WTFCP
# Inserting stock WILDPACK BEVERAGE INC WLDPF
# Inserting stock CUE ENERGY RESOURCES LTD CUEYF
# Inserting stock SHENZHEN EXPRESSWAY CO-H SHZNF
# Inserting stock INSEEGO CORP INSG
# Inserting stock MCHENRY METALS GOLF CORP GLFN
# Inserting stock NEPI ROCKCASTLE PLC-UNSP ADR NEPRY
# Inserting stock NATHAN'S FAMOUS INC NATH
# Inserting stock ROYALTY NORTH PARTNERS LTD RYTTF
# Inserting stock SPDR BBG 1-3MO US TRES USDA SSGBF
# Inserting stock MODERN CINEMA GROUP INC MOCI
# Inserting stock LION CORP LIOPF
# Inserting stock SANDERSON FARMS INC SAFM
# Inserting stock SALMAR ASA SALRF
# Inserting stock TSUTSUMI JEWELRY CO LTD TSSJF
# Inserting stock BATHURST RESOURCES LTD BTURF
# Inserting stock NORTHERN CALIFORNIA BANCORP NRLB
# Inserting stock P10 HOLDINGS INC PIOE
# Inserting stock CENTRAIS ELETRICAS BR-SP ADR EBR
# Inserting stock MONRO INC MNRO
# Inserting stock NATIONWIDE RISK-BASED US EQ RBUS
# Inserting stock NAUTILUS MINERALS INC NUSMF
# Inserting stock SPIRE INC SR.PRA
# Inserting stock TELKONET INC TKOI
# Inserting stock BORNEO RESOURCE INVESTMENTS BRNE
# Inserting stock SEGA SAMMY HOLDING-SPONS ADR SGAMY
# Inserting stock FIDELITY D&D BANCORP INC FDBC
# Inserting stock NEW ZEALAND ENERGY CORP NZERF
# Inserting stock TAI CHEUNG HOLDINGS TAICF
# Inserting stock ADVENT CONVERT & INCOME AVK
# Inserting stock ISHARES EDGE MSCI USA SIZE IUSZF
# Inserting stock NEW WAVE HOLDINGS CORP TRMNF
# Inserting stock PLUS PRODUCTS INC PLPRF
# Inserting stock STANDARD URANIUM LTD STTDF
# Inserting stock COCA-COLA CO/THE KO
# Inserting stock FORTUM OYJ-UNSPONSORED ADR FOJCY
# Inserting stock LAGARDERE SA LGDDF
# Inserting stock GUANAJUATO SILVER CO LTD GSVRF
# Inserting stock VANECK EGYPT EGPT
# Inserting stock VENTOUX CCM ACQUISITION CORP VTAQ
# Inserting stock VALLEY NATIONAL BANCORP VLYPP
# Inserting stock GLOBE INTERNATIONAL LTD GBNLF
# Inserting stock NEW OROPERU RESOURCES INC NOPUF
# Inserting stock NEW YORK TIMES CO-A NYT
# Inserting stock GLOBAL X AUTONOMOUS&ELEC-ETF DRIV
# Inserting stock HOLLYWALL ENTERTAINMENT INC HWAL
# Inserting stock STARPHARMA HOLDINGS LTD SPHRF
# Inserting stock STORNOWAY DIAMOND CORP SWYDF
# Inserting stock B COMMUNICATIONS LTD BCOMF
# Inserting stock CHANGE FINANCE US LARGE CAP CHGX
# Inserting stock ITEKNIK HOLDING CORP ITKH
# Inserting stock VIMEO INC VMEO
# Inserting stock ITAFOS INC MBCF
# Inserting stock AMERICAN BUSINESS CORP ARBU
# Inserting stock CREXENDO INC CXDO
# Inserting stock SLEEP NUMBER CORP SNBR
# Inserting stock ASX LTD ASXFF
# Inserting stock CORPORATE OFFICE PROPERTIES OFC
# Inserting stock ISHARES U.S. HEALTHCARE PROV IHF
# Inserting stock DELTASHARES S&P 400 MGD RISK DMRM
# Inserting stock PHAROL SGPS SA PHRZF
# Inserting stock DIREXION DAILY GOLD MINERS I DUST
# Inserting stock SILVER BEAR RESOURCES PLC SVBRF
# Inserting stock ELECTROCOMPONENTS PLC EENEF
# Inserting stock RRITUAL SUPERFOODS INC RRSFF
# Inserting stock ICLICK INTERACTIVE ASIA-ADR ICLK
# Inserting stock FIREFLY RESOURCES LTD MNDMF
# Inserting stock PROPTECH INV CORP 2 -CW27 PTICW
# Inserting stock CLEARBRIDGE ALL CAP GROWTH E CACG
# Inserting stock LITHIUM CORP LTUM
# Inserting stock SCHWEITZER-MAUDUIT INTL INC SWM
# Inserting stock WARPAINT LONDON PLC WPNTF
# Inserting stock OPTIMUMBANK HOLDINGS INC OPHC
# Inserting stock NUCOR CORP NUE
# Inserting stock YAMATO KOGYO CO LTD YMTKF
# Inserting stock ALFRESA HOLDINGS CORP ARHCF
# Inserting stock FTAC ATHENA ACQUISITION CO-A FTAA
# Inserting stock ARGENTUM SILVER CORP AGSVF
# Inserting stock PARKER DRILLING CO-POST BANK PKDC
# Inserting stock CARLSBERG AS-B-SPON ADR CABGY
# Inserting stock IRPC PCL-UNSP ADR IRPSY
# Inserting stock LION E-MOBILITY AG LMIAF
# Inserting stock PACT GROUP HOLDINGS LTD PTTCF
# Inserting stock WISDOMTREE US MIDCAP DIVIDEN DON
# Inserting stock IFCI INTERNATIONAL CORP IFCI
# Inserting stock EAGLE POINT CREDIT CO ECCX
# Inserting stock INVESCO S&P SMALLCAP FINANCI PSCF
# Inserting stock LUNDBERGS AB-B SHS LBGUF
# Inserting stock TRISTEL PLC TSNLF
# Inserting stock HILTON FOOD GRP - UNSP ADR HLFGY
# Inserting stock SUN SPORTS AND ENTERTAINMENT SUNR
# Inserting stock SOCIAL LIFE NETWORK INC WDLF
# Inserting stock FIRST TRUST NASDQ 100 TECH I QTEC
# Inserting stock FIRST AMERICA RESOURCES CORP FSTJ
# Inserting stock NORDEX SE-UNSPONSORED ADR NRXXY
# Inserting stock E-DIRECT EDZR
# Inserting stock POOL SAFE INC PFFEF
# Inserting stock POLAR PETROLEUM CORP POLR
# Inserting stock SUNAC SERVICES HOLD-UNSP ADR SSHLY
# Inserting stock CIELO SA CIOXF
# Inserting stock NOVUME SOLUTIONS INC-CW23 REKRW
# Inserting stock GRANITE CONSTRUCTION INC GVA
# Inserting stock PENN VIRGINIA CORP PVAC
# Inserting stock INSURAGUEST TECHNOLOGIES INC ISGIF
# Inserting stock ISHARES 1-5 YEAR LADDERED GO CLFMF
# Inserting stock RICHTER GEDEON NYRT-144A ADR GEDRY
# Inserting stock VISTAS MEDIA ACQUISIT -CW26 VMACW
# Inserting stock FERREXPO PLC FEEXF
# Inserting stock CRESCENT COVE ACQ A -CW27 COVAW
# Inserting stock FRONTIER ACQUISITION CORP-A FRON
# Inserting stock ARAVIVE INC ARAV
# Inserting stock BLUE RIBBON INCOME FUND BLUBF
# Inserting stock SUMITOMO CORP SSUMF
# Inserting stock TITAN MEDICAL INC TMDI
# Inserting stock BEE VECTORING TECHNOLOGIES I BEVVF
# Inserting stock INPOST SA INPOF
# Inserting stock JINCHUAN GROUP INTERNATIONAL JGRRF
# Inserting stock QMED INC QMED
# Inserting stock WEST CANYON ENERGY CORP WCYN
# Inserting stock WASECO RESOURCES INC WSRUF
# Inserting stock MITRA KELUARGA KARYASEHAT TB MIKAF
# Inserting stock CITIZENS FINANCIAL GROUP CFG.PRD
# Inserting stock BRYAH RESOURCES LTD BYHFF
# Inserting stock CF ACQUISITION VIII A -CW27 CFFEW
# Inserting stock GRUPO NUTRESA SA-SPON ADR GCHOY
# Inserting stock GEA GROUP AG GEAGF
# Inserting stock CLST HOLDINGS INC CLHI
# Inserting stock PERSIMMON PLC PSMMF
# Inserting stock BOWX ACQUISITION CORP -CW25 BOWXW
# Inserting stock AXFOOD AB-UNSPON ADR AXFOY
# Inserting stock VERBUND AG-SPONS ADR OEZVY
# Inserting stock RIVERNORTH OPPORT MUNI INC RMI
# Inserting stock US COPPER CORP USCUF
# Inserting stock BONESUPPORT HOLDING AB BOEUF
# Inserting stock INNOVENT BIOLOGICS INC IVBXF
# Inserting stock WATERS CORP WAT
# Inserting stock ATLANTIC COASTAL ACQUISITION ACAHU
# Inserting stock FIRST TRUST NASDAQ PHARMACEU FTXH
# Inserting stock DOLLY VARDEN SILVER LTD DOLLF
# Inserting stock MGI DIGITAL GRAPHIC TECHNOLO FRIIF
# Inserting stock POWER RESOURCE EXPLORATION I PREXF
# Inserting stock GAMING & HOSPITALITY A -CW28 GHACW
# Inserting stock GOLDMAN ACTIVEBTA EUR EQ ETF GSEU
# Inserting stock ARTGO HOLDINGS LTD RTGOF
# Inserting stock SCHWAB FUNDAMENTAL SMALL CAP FNDA
# Inserting stock CHINA NONFERROUS GOLD LTD CFEGF
# Inserting stock DECISIONPOINT SYSTEMS INC/CA DPSI
# Inserting stock MIRVAC GROUP MRVGF
# Inserting stock ALTITUDE INTERNATIONAL INC ALTD
# Inserting stock FIRST ENERGY METALS LTD FEMFF
# Inserting stock MALIN CORP PLC MLLNF
# Inserting stock JIUZI HOLDINGS INC JZXN
# Inserting stock KLIMATOR AB KLMAF
# Inserting stock STARPHARMA HOLDINGS-SPON ADR SPHRY
# Inserting stock GLOBAL X MSCI PAKISTAN ETF PAK
# Inserting stock TABCORP HOLDINGS LTD TABCF
# Inserting stock TORTOISE POWER & ENRGY INFRA TPZ
# Inserting stock UPHEALTH INC UPH
# Inserting stock MANDOM CORP MDOMF
# Inserting stock ARBIOS SYSTEMS INC ARBI
# Inserting stock SAINT JEAN CARBON INC TORVF
# Inserting stock OCEAN SPRAY CRANBERRIES INC OCESO
# Inserting stock SABRE CORP SABRP
# Inserting stock CAPITAL & REGIONAL PLC CRPLF
# Inserting stock WECONNECT TECH INTERNATIONAL WECT
# Inserting stock TCW SPECIAL PURPOSE AC- CW28 TSPQ.WS
# Inserting stock GLOBAL X MSCI NORWAY ETF NORW
# Inserting stock PAYSAFE LTD PSFE
# Inserting stock BETAPRO CR OIL -1X DAILY BEA HBTPF
# Inserting stock HORIZON TECHNOLOGY FINANCE C HRZN
# Inserting stock TELIA CO AB TLSNF
# Inserting stock VICTORY OILFIELD TECH INC VYEY
# Inserting stock DUPONT DE NEMOURS INC DD
# Inserting stock XIOR STUDENT HOUSING NV XIORF
# Inserting stock 2G ENERGY AG ZGBEF
# Inserting stock FIRST TRUST DEVELP MKT EX-US FDT
# Inserting stock QS ENERGY INC QSEP
# Inserting stock GALAXY GAMING INC GLXZ
# Inserting stock CLEAN VISION CORP CLNV
# Inserting stock ZZLL INFORMATION TECHNOLOGY ZZLL
# Inserting stock KING ISLAND SCHEELITE LTD KISLF
# Inserting stock AFRICAN GOLD ACQUISITION COR AGAC.U
# Inserting stock JASA MARGA (PERSERO) TB-ADR PTJSY
# Inserting stock SOARING EAGLE ACQU - CL A SRNG
# Inserting stock TORTOISE ACQUISITION CORP A SNPR
# Inserting stock KARORA RESOURCES INC KRRGF
# Inserting stock AVANTOR INC AVTR.PRA
# Inserting stock DOGAN SIRKETLER GRUBU HLDGS DSGUF
# Inserting stock ADVANCED MERGER PARTNERS I-A AMPI
# Inserting stock BLUE WATER PETROLEUM CORP BWPC
# Inserting stock GLOBAL X MSCI CHINA FINANCIA CHIX
# Inserting stock HOWDEN JOINERY GROUP-UNS ADR HWDJY
# Inserting stock PAC ROOTS CANNABIS CORP PACRF
# Inserting stock REVIVAL GOLD INC RVLGF
# Inserting stock AUSNET SERVICES SAUNF
# Inserting stock SUNNY OPTICAL TECH SNPTF
# Inserting stock ABSOLUTE HEALTH AND FITNESS AHFI
# Inserting stock CALMARE THERAPEUTICS INC CTTC
# Inserting stock GLOBAL LOGISTIC PROPERTIES L GBTZF
# Inserting stock PROTALIX BIOTHERAPEUTICS INC PLX
# Inserting stock RANPAK HOLDINGS CORP PACK
# Inserting stock PRIMORSKY SHIPPING CO-SP ADR APSKY
# Inserting stock SONIC FOUNDRY INC SOFO
# Inserting stock PINNACLE WEST CAPITAL PNW
# Inserting stock CAMBRIA TAIL RISK ETF TAIL
# Inserting stock KUROS BIOSCIENCES AG-REG CSBTF
# Inserting stock EMPIRE STATE REALTY OP-S60 OGCP
# Inserting stock ASCOT RESOURCES LTD AOTVF
# Inserting stock ACORDA THERAPEUTICS INC ACOR
# Inserting stock KUALA LUMPUR KEPONG-UNSP ADR KLKBY
# Inserting stock GEORGE RISK INDUSTRIES INC RSKIA
# Inserting stock CITIC RESOURCES HOLDINGS LTD CTJHF
# Inserting stock BANCORP SOUTH BXS.PRA
# Inserting stock ANVIA HOLDINGS CORP ANVV
# Inserting stock CLEARWAY ENERGY INC-A CWEN.A
# Inserting stock G&S MINERALS INC GSML
# Inserting stock MCLOUD TECHNOLOGIES CORP MCLDF
# Inserting stock HIGHLAND TRANSCEND PART-CL A HTPA
# Inserting stock MULTIPLAN CORP-CW25 MPLN.WS
# Inserting stock VMWARE INC-CLASS A VMW
# Inserting stock NOXEL CORP NOXL
# Inserting stock XIAOMI CORP - UNSP ADR XIACY
# Inserting stock NEWNOTE FINANCIAL CORP NWWTF
# Inserting stock MARINE PETROLEUM TRUST MARPS
# Inserting stock UCOMMUNE INTERNATIONAL -CW25 UKOMW
# Inserting stock OMNI-LITE INDUSTRIES CANADA OLNCF
# Inserting stock NUIX LTD NXLLF
# Inserting stock CIRTRAN CORP CIRX
# Inserting stock TURK TELEKOMUNIKASYON AS TRKNF
# Inserting stock RELIANCE GLOBAL -CW26 RELIW
# Inserting stock HAPAG-LLOYD AG HLAGF
# Inserting stock ZOOMINFO TECHNOLOGIES INC-A ZI
# Inserting stock PANBELA THERAPEUTICS INC PBLA
# Inserting stock UNICREDIT SPA-ADR UNCRY
# Inserting stock INFRAESTRUCTURA ENERGETICA N IENVF
# Inserting stock MP MATERIALS CORP MP
# Inserting stock STRATEGIC ASSET LEASING INC LEAS
# Inserting stock SIRIUSPOINT LTD-RIGHT SSPCF
# Inserting stock PREFERRED APARTMENT COMMUNIT APTS
# Inserting stock METROPOLITAN BANK HOLDING CO MCB
# Inserting stock ONE - CLASS A -CW25 MKFG.WS
# Inserting stock MERGENCE CORP MRGN
# Inserting stock EXONE CO/THE XONE
# Inserting stock TAYLOR MORRISON HOME CORP TMHC
# Inserting stock ALEXIS PRACTICAL TACTICAL ET LEXI
# Inserting stock GLOBAL TIRE RECYCLING OF SUM GTRR
# Inserting stock RODEDAWG INTERNATIONAL INDUS RWGI
# Inserting stock JMAX INTERNATIONAL LTD JMEXF
# Inserting stock WESTERN ASSET PREMIER BOND WEA
# Inserting stock PHI GROUP INC/DE PHIG
# Inserting stock STERLING CAPITAL FOCUS EQUIT LCG
# Inserting stock NYSE Tick Pilot TEST NTEST
# Inserting stock DRAGON VICTORY INTERNATIONAL LYL
# Inserting stock 5N PLUS INC FPLSF
# Inserting stock EAGLE NICE (INTL) HLDGS LTD ENIHF
# Inserting stock UNDERGROUND ENERGY CORP UGGYF
# Inserting stock PIONEER MERGER CORP PACXU
# Inserting stock PUBLIC STORAGE PSA.PRH
# Inserting stock FRONTIER ENERGY CORP FRGY
# Inserting stock EUROMONEY INSTL INVESTOR PLC EMYIF
# Inserting stock INTERRA RESOURCES CORP ITRX
# Inserting stock K92 MINING KNTNF
# Inserting stock BRIDGEWATER BANCSHARES INC BWB
# Inserting stock SAINSBURY (J) PLC JSNSF
# Inserting stock FREEDOM ACQUISITION I CORP-A FACT
# Inserting stock CHINA MOLYBDENUM CO LTD-H CMCLF
# Inserting stock JPMORGAN CHASE & CO JPM.PRM
# Inserting stock ICLIMA DIST RENEWABLE ENERGY SHFT
# Inserting stock COMMUNITY HEALTHCARE TRUST I CHCT
# Inserting stock AMERICAN SILVER MINING CO ASLM
# Inserting stock PATRIOT GOLD CORP PGOL
# Inserting stock WEST RED LAKE GOLD MINES INC RLGMF
# Inserting stock METSO OUTOTEC COR UNSPON ADR OUKPY
# Inserting stock NEOLEUKIN THERAPEUTICS INC NLTX
# Inserting stock FLAGSHIP GLOBAL CORP FGCN
# Inserting stock WTB FINANCIAL CORP-CL B WTBFB
# Inserting stock FRESENIUS SE & CO-SPN ADR FSNUY
# Inserting stock UTZ BRANDS INC UTZ
# Inserting stock SIGNET JEWELERS LTD SIG
# Inserting stock DISCOVERY INC-B DISCB
# Inserting stock VAREX IMAGING CORP VREX
# Inserting stock AMERICAN CREEK RESOURCES LTD ACKRF
# Inserting stock CAPRICOR THERAPEUTICS INC CAPR
# Inserting stock DISCOVERY SILVER CORP DSVSF
# Inserting stock ENERGY REVENUE AMERICA INC ERAO
# Inserting stock UNION ACQUISITION COR -CW25 LATNW
# Inserting stock REINVENT TECHNOLOGY PARTNERS RTPYU
# Inserting stock APOLLO HEALTHCARE CORP AHCCF
# Inserting stock CEMENTOS ARGOS SA-SPON ADR CMTOY
# Inserting stock GALA PHARMACEUTICAL INC GLPH
# Inserting stock TEUCRIUM SUGAR FUND CANE
# Inserting stock CHINA LIFE INSURANCE CO-ADR LFC
# Inserting stock COLES GROUP LTD CLEGF
# Inserting stock SPDR NUVEEN MUNICIPAL BOND MBND
# Inserting stock METRO INC/CN MTRAF
# Inserting stock ISHARES ESG AWARE US AGGREGA EAGG
# Inserting stock HAMBURGER HAFEN UND LOGISTIK HHULF
# Inserting stock TITAN MINING CORP TNMCF
# Inserting stock AMERICAN FINANCIAL GROUP AFGE
# Inserting stock SAP SE-SPONSORED ADR SAP
# Inserting stock ASSICURAZIONI GENERALI ARZGF
# Inserting stock HARVEST OIL & GAS CORP HRST
# Inserting stock LLEIDANETWORKS SERVEIS TELEM LLEIF
# Inserting stock REMY COINTREAU-UNSP ADR REMYY
# Inserting stock BEAUTY HEALTH CO/THE SKIN
# Inserting stock GOLDEN AGRI-RESOURCES LTD GARPF
# Inserting stock ISHARES NASDAQ 100 INDEX ETF INQQF
# Inserting stock HOST HOTELS & RESORTS INC HST
# Inserting stock HARPOON THERAPEUTICS INC HARP
# Inserting stock ALTA EQUIPMENT GROUP ALTG.PRA
# Inserting stock PRAXIS PRECISION MEDICINES I PRAX
# Inserting stock TRUESHARES STRUCTURED OUTCOM JUNZ
# Inserting stock CLINIGEN GROUP PLC CLIGF
# Inserting stock MITSUI FUDOSAN CO LTD MTSFF
# Inserting stock ORGHARVEST INC ORGH
# Inserting stock TB SA ACQUISITION A -CW28 TBSAW
# Inserting stock BIOMX INC PHGE
# Inserting stock MEDCO ENERGI INTERNA-UNS ADR MEYYY
# Inserting stock FIRST INDUSTRIAL REALTY TR FR
# Inserting stock VANECK SEMICONDUCTOR SMH
# Inserting stock SIFY TECHNOLOGIES-SPON ADR SIFY
# Inserting stock BROOKFIELD INFRA FIN ULC BIPH
# Inserting stock PENNANTPARK INVESTMENT CORP PNNT
# Inserting stock SIBANYE-STILLWATER LTD-ADR SBSW
# Inserting stock CENTRAL FLORIDA STATE BANK CEFB
# Inserting stock NEXT MEATS HOLDINGS INC NXMH
# Inserting stock TIMBERLINE RESOURCES CORP TLRS
# Inserting stock FORMULAFOLIOS TACTICAL INCOM FFTI
# Inserting stock COMSYS HOLDINGS CORP CMSYF
# Inserting stock CANADIAN UTILITIES LTD B CDUUF
# Inserting stock TOM GROUP LTD TOCOF
# Inserting stock ISHARES CORE DAX DE EUR ACC DAXXF
# Inserting stock GRANITE FALLS ENERGY-MEMB UN GFGY
# Inserting stock NUVEEN QUAL MUNI INCOME FD NAD
# Inserting stock NITORI HLDGS CO LTD-UNSP ADR NCLTY
# Inserting stock RADIUS GLOBAL-CW22 RADIW
# Inserting stock MCDONALD'S CORP MCD
# Inserting stock HABERSHAM BANCORP HABC
# Inserting stock INNOVATOR US EQTY ACCEL PL XTAP
# Inserting stock SOFWAVE MEDICAL LTD SOFWF
# Inserting stock DB CRUDE OIL SHORT EXCHANGE SZOXF
# Inserting stock MEDIA AND GAMES INVEST SE MDGIF
# Inserting stock CROWN SEAL PCL-NVDR CSCPF
# Inserting stock KERRY PROPERTIES LTD KRYPF
# Inserting stock BIOCARDIA INC BCDA
# Inserting stock GENIX PHARMACEUTICALS CORP GENPF
# Inserting stock VIRIDIS HOLDINGS INC VRDSF
# Inserting stock CHINA TOPREACH INC CGSXF
# Inserting stock GELTECH SOLUTIONS INC GLTC
# Inserting stock YDUQS PART-SPONSORED ADR YDUQY
# Inserting stock EFOORA HEALTH MANAGEMENT INC EFOR
# Inserting stock VERY GOOD FOOD CO INC/THE VRYYF
# Inserting stock BMO JUNIOR GOLD INDEX ETF BMJJF
# Inserting stock NATIONWIDE UTILITIES CORP NWUC
# Inserting stock THUNGELA RESOURCES LTD TNGRF
# Inserting stock COLUMBIA INDIA CONSUMER ETF INCO
# Inserting stock IPATH BLOOMBERG COFFEE SUBIN JJOFF
# Inserting stock PINELAWN CEMETERY PLWN
# Inserting stock LIMONEIRA CO LMNR
# Inserting stock OZON HOLDINGS PLC - ADR OZON
# Inserting stock METALINE CONTACT MINES MTLI
# Inserting stock HONG YUAN HOLDING GROUP HGYN
# Inserting stock ISHARES SEMICONDUCTOR ETF SOXX
# Inserting stock NEWS CORP - CLASS B NWS
# Inserting stock COLONIAL COAL INTERNATIONAL CCARF
# Inserting stock IGS CAPITAL GROUP LTD IGSC
# Inserting stock TEST ZXYZ.A
# Inserting stock BIOMIMIX INC BMMX
# Inserting stock MICROPORT CARDIOF - UNSP ADR MCRCY
# Inserting stock SAPIENS INTERNATIONAL CORP SPNS
# Inserting stock AF ACQUISITION CORP AFAQU
# Inserting stock INDUSTRIAL TECH ACQUIS- CL A ITAC
# Inserting stock GLASS HOUSES ACQUISITION COR GLHAU
# Inserting stock HARBOR CUSTOM DEVEL -CW26 HCDIW
# Inserting stock ALLIED CORP ALID
# Inserting stock CHURCHILL DOWNS INC CHDN
# Inserting stock PUBLIC STORAGE PSA.PRE
# Inserting stock VELOCITYSHARES 3X LONG GOLD UGLDF
# Inserting stock EVERCOMMERCE INC EVCM
# Inserting stock HAVERTY FURNITURE COS-CL A HVT.A
# Inserting stock INVESCO S&P INTERNATIONAL DE IDLV
# Inserting stock GLOBAL X TARGETINCOME PLUS 2 TFLT
# Inserting stock CANADIAN GOLDCAMPS CORP SMATF
# Inserting stock ISHARES CORE MSCI EMU EUR A XMTIF
# Inserting stock COEPTIS THERAPEUTICS INC COEP
# Inserting stock LIQUID HOLDINGS GROUP INC LIQDQ
# Inserting stock GMO INTERNET INC-UNSP ADR GMYOY
# Inserting stock WORTHINGTON INDUSTRIES WOR
# Inserting stock MEDCOLCANNA ORGANICS INC MCCNF
# Inserting stock NOVOLIPETSK STEEL-GDR 144A NISQY
# Inserting stock WHOLE EARTH BRANDS INC FREE
# Inserting stock AMERICAN PACIFIC RIM COMMERC APRM
# Inserting stock TIANRONG MED GROUP INC TNMD
# Inserting stock WESTKAM GOLD CORP WKGFF
# Inserting stock HYUNDAI MOBIS CO LTD HYPLF
# Inserting stock BAIDU INC - SPON ADR BIDU
# Inserting stock MANOLETE PARTNERS PLC MANOF
# Inserting stock HANGZHOU TIGER - UNSP ADR HNGZY
# Inserting stock COMPASS MINERALS INTERNATION CMP
# Inserting stock STRYVE FOODS INC-CLASS A SNAX
# Inserting stock INTERNETARRAY INC INAR
# Inserting stock BANK OF AMERICA CORP BML.PRJ
# Inserting stock HOVNANIAN ENTERPRISES HOVNP
# Inserting stock PLANT-BASED INVESTMENT CORP CWWBF
# Inserting stock MARATHON BANCORP INC MBBC
# Inserting stock POSTD MERCHANT BANQUE PMBY
# Inserting stock YOKOHAMA RUBBER CO LTD YORUF
# Inserting stock B. RILEY PRINCIPAL MER -CW26 EOSEW
# Inserting stock Test ZZZ
# Inserting stock TOPPAN INC-APON ADR TOPPY
# Inserting stock TWIN RIDGE CAPITAL ACQUISI-A TRCA
# Inserting stock TOWNE BANK TOWN
# Inserting stock SYNAPTICS INC SYNA
# Inserting stock NEWTEK BUSINESS SERVICES NEWTZ
# Inserting stock CSPC PHARMACEUTICAL GROUP LT CHJTF
# Inserting stock SVF INVESTMENT CL A -CW27 SVFAW
# Inserting stock FLEXSHARES DEVELOPED MARKETS QLVD
# Inserting stock ANTILIA GROUP CORP AGGG
# Inserting stock NEW ZEALAND OIL-UNSP ADR NZEOY
# Inserting stock CP ALL PCL-FOREIGN CVPBF
# Inserting stock ARC RESOURCES LTD AETUF
# Inserting stock HANSTONE GOLD CORP HANCF
# Inserting stock SYMBIO PHARMACEUTICALS LTD SBIZF
# Inserting stock CALIFORNIA NANOTECHNOLOGIES CANOF
# Inserting stock FIRST HORIZON CORP FHN.PRF
# Inserting stock WEST FRASER TIMBER CO LTD WFG
# Inserting stock BANPU PUBLIC CO LTD-NVDR BNPJF
# Inserting stock FILO MINING CORP FLMMF
# Inserting stock UWHARRIE CAPITAL CORP UWHR
# Inserting stock STARTECH LABS INC LAAB
# Inserting stock CHESAPEAKE ENERGY -CW26 CHKEZ
# Inserting stock ISHARES CORE TOTAL BOND ETF IUSB
# Inserting stock SHINKO SHOJI CO LTD SKSJF
# Inserting stock SOUTH JERSEY INDUSTRIES SJIV
# Inserting stock EXTREME NETWORKS INC EXTR
# Inserting stock TEAM17 GROUP PLC TSVNF
# Inserting stock HOLLEY INC HLLY
# Inserting stock OTONOMY INC OTIC
# Inserting stock SOUTH STATE CORP SSB
# Inserting stock ESKAY MINING CORP ESKYF
# Inserting stock SOFTWARE ACQUISITION G -CW25 CURIW
# Inserting stock UNITED STATES 12 MONTH OIL USL
# Inserting stock SUBAYE INC SBAY
# Inserting stock FIRST TRUST LARGE CAP CORE A FEX
# Inserting stock ACER INC-SPONSORED GDR REG S ACEYY
# Inserting stock BIOSIG TECHNOLOGIES INC BSGM
# Inserting stock DELTA LLOYD NV DLLLF
# Inserting stock MOBILESMITH INC MOST
# Inserting stock NEWRIVER REIT PLC NRWRF
# Inserting stock NEWHOLD INVESTMENT A -CW26 EVLVW
# Inserting stock SILVERBOX ENGAGED MERGER COR SBEAU
# Inserting stock ISHARES GLOBAL AGRICULTURE I CLYAF
# Inserting stock CYIOS CORP CYIO
# Inserting stock TYNER RESOURCES LTD TIPNF
# Inserting stock PROTEXT MOBILITY INC TXTM
# Inserting stock ABF PAN ASIA BOND INDEX -USD ABFXF
# Inserting stock GLOBE PHOTOS INC GBPT
# Inserting stock ACUSHNET HOLDINGS CORP GOLF
# Inserting stock ACT II GLOBAL ACQUISITI-CW24 FREEW
# Inserting stock NEXEON MEDSYSTEMS INC NXNN
# Inserting stock PIMCO ACTIVE BOND EXCHANGE-T BOND
# Inserting stock GRUPO CLARIN S-CL B GDR 144A GRCLY
# Inserting stock PROSPEROUS FUTURE HOLDINGS L PRFUF
# Inserting stock SYNCHRONY FINANCIAL SYF
# Inserting stock METEN EDTECHX EDUCATION GROU METXW
# Inserting stock VANGUARD S&P SMALL-CAP 600 G VIOG
# Inserting stock VOR BIOPHARMA INC VOR
# Inserting stock COM-GUARD.COM INC CGUD
# Inserting stock TOPBUILD CORP BLD
# Inserting stock K2 GOLD CORP KTGDF
# Inserting stock LIANDI CLEAN TECHNOLOGY INC LNDT
# Inserting stock PETRA ACQUISITION INC PAICU
# Inserting stock ANDO HOLDINGS LTD ADHG
# Inserting stock BUBBLR INC BBLR
# Inserting stock ASTRA AGRO LESTARI-UNSP ADR AAGRY
# Inserting stock CONVENTIVE TECHNOLOGIES LTD CVTTF
# Inserting stock REX INTERNATIONAL HOLDING REXHF
# Inserting stock EVERBRIDGE INC EVBG
# Inserting stock ABV CONSULTING INC ABVN
# Inserting stock TRINITY RESOURCES INC TRRI
# Inserting stock ID PERFUMES INC IDPE
# Inserting stock HWGG ENTERTAINMENT LTD HWGG
# Inserting stock LAI SUN GARMENT INTL-SP ADR LGRTY
# Inserting stock KENTUCKY FIRST FEDERAL BANCO KFFB
# Inserting stock SPAREBANK 1 RINGERIKE HADELA RGKSF
# Inserting stock METAL TIGER PLC MRTTF
# Inserting stock REDEFY CORP RDCO
# Inserting stock JPM BETABUILDERS INTL EQTY BBIN
# Inserting stock AUSTEVOLL SEAFOOD ASA ASTVF
# Inserting stock CANOPY GROWTH CORP CGC
# Inserting stock GLOBAL X FTSE NORDIC REGION GXF
# Inserting stock IMMUNE THERAPEUTICS INC IMUN
# Inserting stock X4 PHARMACEUTICALS INC XFOR
# Inserting stock WIRELESS XCESSORIES GROUP WIRX
# Inserting stock BFI FINANCE INDONESIA TBK PT PBIIF
# Inserting stock KLX ENERGY SERVICES HOLDING KLXE
# Inserting stock SOUND GLOBAL LTD SGXXF
# ...
# Inserting stock NS8 CORP NSEO
# Inserting stock FIGS INC-CLASS A FIGS
# Inserting stock AMAZON.COM INC AMZN
# Inserting stock UNIGOLD INC UGDIF
# Inserting stock SUPER MICRO COMPUTER INC SMCI
# Inserting stock SSY GROUP LTD LJUIF
# Inserting stock FLEXSHARES GLOBAL UPSTREAM N GUNR
# Inserting stock XILINX INC XLNX
# Inserting stock NOMURA REAL ESTATE MASTER FU NMMRF
# Inserting stock ZHANGMEN EDUCATION INC- ADR ZME
# Inserting stock NEW YORK MORTGAGE TRUST NYMTL
# Inserting stock DIVERSIFIED ENERGY HOLDINGS DIEN
# Inserting stock PROSHARES S&P TECH DVD ARIST TDV
# Inserting stock SP/F S&P GLOBAL REIT SHARIA SPRE
# Inserting stock CLOUDWARD INC CDWD
# Inserting stock INCAPTA INC INCT
# Inserting stock MARTEN TRANSPORT LTD MRTN
# Inserting stock ACORN ENERGY INC ACFN
# Inserting stock ISHARES MSCI UAE ETF UAE
# Inserting stock FRONTIER LITHIUM INC LITOF
# Inserting stock LVMH MOET HENNESSY-UNSP ADR LVMUY
# Inserting stock SEKISUI CHEMICAL-UNSPON ADR SKSUY
# Inserting stock CYAN AG-NEW CCYNF
# Inserting stock GROUP ELEVEN RESOURCES CORP GRLVF
# Inserting stock SHEPHERD NEAME LTD SPHNF
# Inserting stock ENERGY FOCUS INC EFOI
# Inserting stock ANGIOGENEX INC AGGX
# Inserting stock EAST SIDE FINANCIAL ESDF
# Inserting stock JIANPU TECHNOLOGY INC-SP ADR JT
# Inserting stock LOGISTEC CORP - CLASS B LTKBF
# Inserting stock RENTOKIL INITIAL PLC-SP ADR RTOKY
# Inserting stock TAOKAENOI FOOD & MARKETING P TKAEF
# Inserting stock PROSHRS RSL 2000 DVD GRW ETF SMDV
# Inserting stock NANOBAC PHARMACEUTICALS INC NNBP
# Inserting stock ABERFORTH SMALLER COS-ORD ABFRF
# Inserting stock LOTUS VENTURES INC LTTSF
# Inserting stock EQUITY COMMONWEALTH EQC.PRD
# Inserting stock SEMRUSH HOLDINGS INC-A SEMR
# Inserting stock FT CBOE VEST U.S. EQUITY DEE DJUN
# Inserting stock COSTCO WHOLESALE CORP COST
# Inserting stock SYMPHONY INTERNATIONAL HOLDI SYNNF
# Inserting stock FLAHERTY & CRUMRINE PREFERRE PFO
# Inserting stock PIMCO CALIFORNIA MUNICIP III PZC
# Inserting stock NAPSTER GROUP PLC EVVRF
# Inserting stock CLEAN HARBORS INC CLH
# Inserting stock SELECT INTERIOR CONCEPTS-A SIC
# Inserting stock ISHARES AGENCY BOND ETF AGZ
# Inserting stock PROSHARES TRUST-S&P 500 EX-H SPXV
# Inserting stock ARROW ELECTRONICS INC ARW
# Inserting stock EXTRACTION OIL & GAS INC XOG
# Inserting stock NANOTECH ENTERTAINMENT INC NTEK
# Inserting stock PACER TRENDPILOT EUROPEAN ET PTEU
# Inserting stock NEWHYDROGEN INC NEWH
# Inserting stock YAMATO HOLDINGS CO-UNSP ADR YATRY
# Inserting stock MANNING & NAPIER INC MN
# Inserting stock COMPUTER ENGINEER & CONSULT CMECF
# Inserting stock LEON'S FURNITURE LTD LEFUF
# Inserting stock MARLIN BUSINESS SERVICES INC MRLN
# Inserting stock COGECO INC CGECF
# Inserting stock CUBA BEVERAGE CO CUBV
# Inserting stock FALCON MINERALS CORP FLMN
# Inserting stock ALLEGIANT TRAVEL CO ALGT
# Inserting stock NOBLE ROCK ACQUISITION COR-A NRAC
# Inserting stock NEOGENOMICS INC NEO
# Inserting stock GIVOT OLAM OIL EXPLORAT- LP GOOXF
# Inserting stock REYSAS LOGISTICS RYSKF
# Inserting stock SUPERMAX CORP BHD SPMXF
# Inserting stock VIABUILT VENTURES INC VBVT
# Inserting stock RED EAGLE MINING CORP RDEMF
# Inserting stock GLOBAL X GURU INDEX ETF GURU
# Inserting stock ANGSTROM TECHNOLOGIES INC AGTT
# Inserting stock INNOVATOR SP 500 ULTRA - FEB UFEB
# Inserting stock SCION TECH GROWTH II -CW27 SCOBW
# Inserting stock BIOTRICITY INC BTCY
# Inserting stock NEW GERMANY FUND GF
# Inserting stock AAREAL BANK AG AAALF
# Inserting stock KODIAK SCIENCES INC KOD
# Inserting stock JUFEEL INTERNATIONAL GROUP CNJG
# Inserting stock TOPPAN INC TONPF
# Inserting stock MITSUBISHI MATERIALS CORP MIMTF
# Inserting stock RM2 INTERNATIONAL SA RMISF
# Inserting stock CHINA HONGQIAO GR-UNSPON ADR CHHQY
# Inserting stock KALERA AS KSLLF
# Inserting stock WHITBREAD PLC WTBCF
# Inserting stock RIVERNORTH FLEXIBLE MUNI RFM
# Inserting stock HYRECAR INC HYRE
# Inserting stock COSMO ENERGY HOLD-UNSP ADR CSGYY
# Inserting stock ASCENDAS REAL ESTATE INV TRT ACDSF
# Inserting stock COSTAR GROUP INC CSGP
# Inserting stock JOANN INC JOAN
# Inserting stock JPMORGAN BETABUILDERS JAPAN BBJP
# Inserting stock EDENRED SA-UNSP ADR EDNMY
# Inserting stock ISHARES EUROPE CONS STP EURA IRXTF
# Inserting stock ENDEAVOUR SILVER CORP EXK
# Inserting stock AO WORLD PLC AOWDF
# Inserting stock EROS RESOURCES CORP EROSF
# Inserting stock GUARDIAN CAP GRP LTD-CL A GCAAF
# Inserting stock WARRIOR TECHNOLOGIES ACQUISI WARR.U
# Inserting stock WELLS FARGO & COMPANY WFC.PRD
# Inserting stock BARINGS PARTICIPATION INVEST MPV
# Inserting stock OASIS MIDSTREAM PARTNERS LP OMP
# Inserting stock INTEGA GROUP LTD IGRXF
# Inserting stock YUEXIU REAL ESTATE INVESTMEN YUXXF
# Inserting stock DIGITALBRIDGE GROUP INC DBRG.PRG
# Inserting stock ANNEXIN PHARMACEUTICALS AB ANXNF
# Inserting stock STAR ENTERTAINMENT GRP LTD/T EHGRF
# Inserting stock FS KKR CAPITAL CORP FSK
# Inserting stock FLSMIDTH & CO A/S FLIDF
# Inserting stock JPX GLOBAL INC JPEX
# Inserting stock INVESCO BULLETSHARES 2025 CO BSCP
# Inserting stock EC WORLD REIT ECWDF
# Inserting stock IPATH SERIES B BBG PRECIOUS JJP
# Inserting stock BROADSCALE ACQUISITION -CL A SCLE
# Inserting stock WEED GROWTH FUND INC WEDG
# Inserting stock RELAY THERAPEUTICS INC RLAY
# Inserting stock ABINGDON HEALTH PLC ABDXF
# Inserting stock NAVER CORP NHNCF
# Inserting stock DREAM OFFICE REAL ESTATE INV DRETF
# Inserting stock LIV CAPITAL ACQUISITION CO-A LIVK
# Inserting stock RENOVATE NEIGHBORHOODS INC RNVT
# Inserting stock TRULIEVE CANNABIS CORP TCNNF
# Inserting stock KIMCO REALTY CORP KIM.PRM
# Inserting stock JOHN HANCOCK INCOME SECS TR JHS
# Inserting stock GREEN STREET CAPITAL CORP JAGR
# Inserting stock BP PLC BPAQF
# Inserting stock MUNTERS GROUP AB MMNNF
# Inserting stock GAN LTD GAN
# Inserting stock SEVEN OAKS ACQUISITION CORP SVOKU
# Inserting stock ACCIONA SA ACXIF
# Inserting stock ARCELORMITTAL SOUTH-SPN ADR AMSIY
# Inserting stock ROCKHAVEN RESOURCES LTD RKHNF
# Inserting stock CONX CORP-CLASS A -CW27 CONXW
# Inserting stock MATSUI SECURITIES CO LTD MTSEF
# Inserting stock GROM SOCIAL ENTERPRISE -CW28 GROMW
# Inserting stock SABRE RESOURCES LTD SAREF
# Inserting stock SENTRY TECHNOLOGY CORP SKVY
# Inserting stock ROBINSONS RETAIL-UNSP ADR RRETY
# Inserting stock IOVANCE BIOTHERAPEUTICS INC IOVA
# Inserting stock KASHIN INC KUSA
# Inserting stock HOUGHTON MIFFLIN HARCOURT CO HMHC
# Inserting stock PERK LABS INC PKLBF
# Inserting stock BEDFORD ENERGY INC BFDE
# Inserting stock MYCELX TECHNOLOGIES CORP-ADD MYCX
# Inserting stock REKO INTERNATIONAL GROUP INC RKIGF
# Inserting stock ENTHEOS CAPITAL CORP WFGCF
# Inserting stock GERRESHEIMER AG-UNSP ADR GRRMY
# Inserting stock PROSHARES ULTRASHORT AUD CROC
# Inserting stock FIRST TRUST WATER ETF FIW
# Inserting stock L&G ROBO GLOBAL ROBOTICS&AUT RBGBF
# Inserting stock EDWARDS LIFESCIENCES CORP EW
# Inserting stock ENVIRONMENTAL WASTE INTL INC YEWTF
# Inserting stock HDFC BANK LTD-ADR HDB
# Inserting stock STERLING CONSTRUCTION CO STRL
# Inserting stock HOMASOTE COMPANY HMTC
# Inserting stock MOUNTAIN PACIFIC BANCORP INC MPCB
# Inserting stock FUTURE INTERNATIONAL GROUP C FIGM
# Inserting stock ING BANK SLASKI SA-UNSP ADR INGKY
# Inserting stock ITACONIX PLC ITXXF
# Inserting stock MARQUEE RAINE ACQUISITION CO MRACU
# Inserting stock MINDBEACON HOLDINGS INC MBCHF
# Inserting stock MAGYAR TELEKOM TELE-SPON ADR MYTAY
# Inserting stock CONNECTICUT RIVER COMMUNITY CRCA
# Inserting stock MONTELLO RESOURCES LTD MLORF
# Inserting stock BEYOND MEDICAL TECHNOLOGIES DOCKF
# Inserting stock NUVEEN FLOAT RATE INC FD JFR
# Inserting stock TAIGA MOTORS CORP TAIMF
# Inserting stock UBS ETF MSCI SWITZ H USD UBANF
# Inserting stock WALDENCAST ACQ CL A -CW27 WALDW
# Inserting stock SACGASCO LTD ATRLF
# Inserting stock PIEDMONT COMMUNITY BANK GROU PCBN
# Inserting stock CEDAR REALTY TRUST INC CDR.PRB
# Inserting stock HAWK PROTECTION SYSTEMS INC HWPR
# Inserting stock CGN MINING CO LTD CGNMF
# Inserting stock BOEING CO/THE BA
# Inserting stock DECKER MANUFACTURING CORP DMFG
# Inserting stock LOGICQUEST TECHNOLOGY INC LOGQ
# Inserting stock RAVEN INDUSTRIES INC RAVN
# Inserting stock JPMORGAN AMERICAN INVEST-ORD JFAIF
# Inserting stock PERSHING RESOURCES CO INC PSGR
# Inserting stock AEVIS VICTORIA SA AEVIF
# Inserting stock SUZUKEN CO LTD SZUKF
# Inserting stock ALKAMI TECHNOLOGY INC ALKT
# Inserting stock Gabelli Multimedia Trust Inc GGT.RT
# Inserting stock BREWBILT MANUFACTURING INC BBRW
# Inserting stock BLACKROCK HIGH YIELD MUNI IN HYMU
# Inserting stock GLOBAL DIV INV GRADE INC II GIIZF
# Inserting stock OTSUKA CORP OSUKF
# Inserting stock PGS ASA-ADR PGSVY
# Inserting stock MAIRS & POWER MN MUNI BOND MINN
# Inserting stock WASTE CONNECTIONS INC WCN
# Inserting stock LXRANDCO INC-CLASS B GGBBF
# Inserting stock MMG LTD MMLTF
# Inserting stock PSI SOFTWARE AG PSSWF
# Inserting stock CHESAPEAKE GOLD CORP CHPGF
# Inserting stock ISHARES UK GILTS 0-5YR UCITS ISHZF
# Inserting stock CENTURY GLOBAL COMMODITIES C CEUMF
# Inserting stock ABOITIZ POWER CORP-UNSP ADR ABZPY
# Inserting stock AVANTIS EMERGING MARKETS EQ AVEM
# Inserting stock WALMART DE MEXICO SAB DE CV WMMVF
# Inserting stock DIVERSEY HOLDINGS LTD DSEY
# Inserting stock COMMUNITY HERITAGE FINANCIAL CMHF
# Inserting stock CYBERAGENT INC CYAGF
# Inserting stock SECURITY FEDERAL CORP SFDL
# Inserting stock EJF ACQUISITION CORP-A EJFA
# Inserting stock KLUDEIN I ACQUISITION-CW27 INKAW
# Inserting stock ARANJIN RESOURCES LTD FVVSF
# Inserting stock BK TECHNOLOGIES CORP BKTI
# Inserting stock RICH PHARMACEUTICALS INC RCHA
# Inserting stock CYCLERION THERAPEUTICS INC CYCN
# Inserting stock ZHONGSHENG GROUP-UNSP ADR ZSHGY
# Inserting stock INVIVO THERAPEUTICS HOLDINGS NVIV
# Inserting stock SANTOS LTD STOSF
# Inserting stock ALLIANZIM US LG CAP BUFFER20 AZBA
# Inserting stock VANECK RUSSIA SMALL-CAP RSXJ
# Inserting stock EQK REALTY INVESTORS I EQKR
# Inserting stock IMINE CORP JRVS
# Inserting stock PONIARD PHARMACEUTICALS INC PARD
# Inserting stock BLACKSTONE LONG-SHORT CREDIT BGX
# Inserting stock KAISA PROSPERITY HOLDINGS LT KKPFF
# Inserting stock BLOOMIOS INC BLMS
# Inserting stock SPOTLIGHT CAPITAL HOLDINGS I SLCH
# Inserting stock XPERI HOLDING CORP XPER
# Inserting stock BLACKROCK MUNIHOLDINGS QUALI MFL
# Inserting stock DZS INC DZSI
# Inserting stock DATASEA INC DTSS
# Inserting stock CHINA NETWORK MEDIA INC CNNM
# Inserting stock ISHARES INC ISHARES ESG AWAR ESGE
# Inserting stock CONCORDE AMERICA INC CNDD
# Inserting stock IBSG INTERNATIONAL INC IBIN
# Inserting stock FACTSET RESEARCH SYSTEMS INC FDS
# Inserting stock SURUGA BANK LTD SRGBF
# Inserting stock SCOUT24 AG SCOTF
# Inserting stock FONDUL PROPRIETATEA SA/FUND FDLPF
# Inserting stock GLOBAL X EM INTERNET & ECOMM EWEB
# Inserting stock GENIUS BRANDS INTERNATIONAL GNUS
# Inserting stock PARATEK PHARMACEUTICALS INC PRTK
# Inserting stock VEECO INSTRUMENTS INC VECO
# Inserting stock ATRESMEDIA CORP DE MEDIOS DE AIOSF
# Inserting stock QTS REALTY TRUST INC QTS.PRB
# Inserting stock EVELO BIOSCIENCES INC EVLO
# Inserting stock POPULATION HEALTH CL A -CW25 PHICW
# Inserting stock ORSU METALS CORP ORSUF
# Inserting stock CALLOWAY'S NURSERY INC CLWY
# Inserting stock HUNTER MARITIME ACQUISITION HUNTF
# Inserting stock FINGERPRINT CARDS AB-B FGRRF
# Inserting stock GRUPO AEROPORTUARIO PAC-ADR PAC
# Inserting stock CONNECTED MEDIA TECHNOLGIES CNCM
# Inserting stock STAGWELL INC STGW
# Inserting stock AVANGARDCO INVESTMEN-SPN ADR AGVDY
# Inserting stock INTERPACE BIOSCIENCES INC IDXG
# Inserting stock ISHARES JPM USD EM CRP USD A ISJMF
# Inserting stock VANECK MORNINGST US MOAT ETF VCKVF
# Inserting stock HEXCEL CORP HXL
# Inserting stock ONCOLYTICS BIOTECH INC ONCY
# Inserting stock KRANESHARES MSCI ALL CHINA I KALL
# Inserting stock GREEN PLANET BIO ENGINEERING GPLB
# Inserting stock TRANSATLANTIC CAPITAL INC TACI
# Inserting stock CAPITAL ONE FINANCIAL CO COF.PRN
# Inserting stock BIONOMICS LTD BNOEF
# Inserting stock FLAMERET INC FLRE
# Inserting stock MAINSTREET FINANCIAL CORP MSFN
# Inserting stock MINDSET PHARMA INC MSSTF
# Inserting stock SONY GROUP CORP - SP ADR SONY
# Inserting stock KEPPEL DC REIT KPDCF
# Inserting stock SPECTRA7 MICROSYSTEMS INC SPVNF
# Inserting stock PUBLIC STORAGE PSA.PRG
# Inserting stock SPDR BBG BARC 1-3 MONTH TBIL BIL
# Inserting stock DIAGEO PLC DGEAF
# Inserting stock HERTZ GLOBAL HLDGS INC -CW51 HTZZW
# Inserting stock TERNA ENERGY SA-UNSP ADR TREAY
# Inserting stock CCK CONSOLIDATED-CW23 CCKWF
# Inserting stock TAILWIND INTERNATIONAL ACQ-A TWNI
# Inserting stock IMPERIAL HELIUM CORP IMPHF
# Inserting stock NAGOYA RAILROAD CO LTD NARRF
# Inserting stock XD INC XDNCF
# Inserting stock RWE AKTIENGESELLSCHAF-SP ADR RWEOY
# Inserting stock PEABODY ENERGY CORP BTU
# Inserting stock SOUTHERN BANCSHARES INC/N C SBNC
# Inserting stock YARA INTERNATIONAL-ADR YARIY
# Inserting stock SUPERIOR GROUP OF COS INC SGC
# Inserting stock TERNS PHARMACEUTICALS INC TERN
# Inserting stock PRADA S.P.A. PRDSF
# Inserting stock X USD TREASURIES 1-3 XTRSF
# Inserting stock SEPTENI HOLDINGS-UNSP ADR SPIDY
# Inserting stock ELANCO ANIMAL HEALTH INC ELAT
# Inserting stock PROSHARES ULTRA REAL ESTATE URE
# Inserting stock ORIGIN MATERIALS INC ORGN
# Inserting stock ALSERES PHARMACEUTICALS INC ALSE
# Inserting stock EL MANIEL INTERNATIONAL INC EMLL
# Inserting stock PXP ENERGY CORP PXPEF
# Inserting stock DRONE GUARDER INC DRNG
# Inserting stock NSD CO LTD NPSYF
# Inserting stock WECOMMERCE HOLDINGS LTD WECMF
# Inserting stock JEFFERIES FINANCIAL GROUP IN JEF
# Inserting stock GLOBAL X AGTECH & FOOD INNOV KROP
# Inserting stock FORTRESS BIOTECH INC FBIOP
# Inserting stock TVI PACIFIC INC TVIPF
# Inserting stock TEMENOS AG-SP ADR TMSNY
# Inserting stock NORWEGIAN ENERGY CO ASA NRWEF
# Inserting stock KINNEVIK AB - B KNKBF
# Inserting stock WALKER RIVER RESOURCES CORP WRRZF
# Inserting stock HECLA MINING CO HL
# Inserting stock KELLY SERVICES INC -CL B KELYB
# Inserting stock INVESCO BULLETSHARE 2028 HYC BSJS
# Inserting stock AMERICAN CUMO MINING CORP MLYCF
# Inserting stock FIRST COLOMBIA GOLD CORP FCGD
# Inserting stock TOSOH CORP TOSCF
# Inserting stock NICOLA MINING INC HUSIF
# Inserting stock MONEYONMOBILE INC MOMT
# Inserting stock FAR PEAK ACQUISITION CORP-A FPAC
# Inserting stock SOUTHWEST GAS HOLDINGS INC SWX
# Inserting stock DOUYU INTERNATIONAL HOLD-ADR DOYU
# Inserting stock FIRST GRAPHENE LTD FGPHF
# Inserting stock NOVA CANNABIS INC NVACF
# Inserting stock ISHARES FLOATING RATE BOND E FLOT
# Inserting stock FIDELITY CON DISCRET ETF FDIS
# Inserting stock CREDIT AGRICOLE SA CRARF
# Inserting stock HELIUS MEDICAL TECH -CW26 HSDTW
# Inserting stock ARCTIC STAR EXPLORATION CORP ASDZF
# Inserting stock BUZZI UNICEM SPA BZZUF
# Inserting stock ESCON JAPAN REIT INVESTMENT ESCNF
# Inserting stock VANGU USDTRBD USDA VRGFF
# Inserting stock CAIXABANK- UNSPON ADR CAIXY
# Inserting stock ISHARES CORE EURO STOXX50 DE IDJEF
# Inserting stock JIANGSU EXPRESS CO-SPONS ADR JEXYY
# Inserting stock QURATE RETAIL GROUP INC-B QRTEB
# Inserting stock SEIKO EPSON CORP SEKEF
# Inserting stock CHOICEONE FINANCIAL SVCS INC COFS
# Inserting stock FEVERTREE DRINKS PLC FQVTF
# Inserting stock TAKASAGO INTERNATIONAL CORP TKINF
# Inserting stock SMART MOVE INC SMVE
# Inserting stock HARVEY NORMAN HLD-UNSPON ADR HNORY
# Inserting stock NUVEEN SEL TX-FR INC PORT 2 NXQ
# Inserting stock SIGMABROADBAND CO SGRB
# Inserting stock LYNX GLOBAL DIGITAL FINANCE CNONF
# Inserting stock RION CO LTD RIOXF
# Inserting stock BLACK DIAMOND GROUP LTD BDIMF
# Inserting stock TONOPAH DIVIDE MINING TODM
# Inserting stock INOGEN INC INGN
# Inserting stock LIONHUB GROUP LTD LNHBF
# Inserting stock EUROPEAN BIOTECH ACQUISITION EBACU
# Inserting stock UNITY BANCORP INC UNTY
# Inserting stock VIRTUS REAL ASSET INCOME ETF VRAI
# Inserting stock BLACKROCK WORLD MINING TRUST BWMTF
# Inserting stock SOCKET MOBILE INC SCKT
# Inserting stock DFCITY GROUP BHD- SPON ADR HHKSY
# Inserting stock LIVE OAK BANCSHARES INC LOB
# Inserting stock ERICKSON INC EKSN
# Inserting stock PIXELWORKS INC PXLW
# Inserting stock WR GRACE & CO GRA
# Inserting stock MFA FINANCIAL INC MFA.PRC
# Inserting stock ECOGREEN INTERNATIONAL GROUP ECOCF
# Inserting stock PANASONIC CORP PCRFF
# Inserting stock SKYE BIOSCIENCE INC SKYE
# Inserting stock WISDOMTREE EMERGING MARKETS EMMF
# Inserting stock MABUCHI MOTOR CO LTD MBUMF
# Inserting stock FACEKEY CORP FAKC
# Inserting stock MONDI PLC MONDF
# Inserting stock WEBJET LTD - UNSP ADR WEJTY
# Inserting stock WASHINGTON TRUST BANCORP WASH
# Inserting stock HOME BANCSHARES INC HOMB
# Inserting stock SPIRAX-SARCO ENGIN-UNSP ADR SPXSY
# Inserting stock GUNGNIR RESOURCES INC ASWRF
